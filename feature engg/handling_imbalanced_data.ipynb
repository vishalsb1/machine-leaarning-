# %%
# !pip install scikit-learn

# %%
from sklearn.datasets import make_classification

# %%
x,y=make_classification(n_samples=1000,n_redundant=0,n_features=2,n_clusters_per_class=1,
                    weights=[0.9],random_state=12)

# %%
import pandas as pd

df1=pd.DataFrame(x,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])

final_df=pd.concat([df1,df2],axis=1)

final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])

# %%
# now we will learn how smote works
! pip install imblearn

# %%
from imblearn.over_sampling import SMOTE # type: ignore

# %%
over_sampled=SMOTE()

x,y=over_sampled.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
x.shape
# Out:
# (1800, 2)

# %%
y.shape
# Out:
# (1800,)

# %%
df1=pd.DataFrame(x,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])

over_sampled=pd.concat([df1,df2],axis=1)

# %%
plt.scatter(over_sampled['f1'],over_sampled['f2'],c=over_sampled['target'])
