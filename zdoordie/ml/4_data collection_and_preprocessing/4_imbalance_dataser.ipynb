# %%
import numpy as np 
import pandas as pd

# %%
credit_card_data=pd.read_csv('/workspaces/machine-leaarning-/zdoordie/ml/4_data collection_and_preprocessing/4_credit_data.csv')

# %%
credit_card_data.head(7)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# ...

# %%
credit_card_data
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0            0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1            0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2            1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3            1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4            2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...          ...       ...       ...       ...       ...       ...       ...
# 187762  127681.0  1.901463  0.552643 -0.481182  3.944113  0.335964 -0.109623
# 187763  127681.0  2.100227  0.321608 -2.548285  0.458166  0.954416 -1.241859
# 187764  127681.0  2.235807 -0.996976 -1.058469 -1.124942 -0.420362  0.189049
# 187765  127681.0 -0.999690  0.681567 -2.753857 -0.374143  1.728585 -1.147355
# 187766  127682.0  1.910744 -0.885991 -0.392436  0.947652 -0.961851 -0.222081
#
# ...

# %%
credit_card_data['Class'].value_counts()

# 0.0 legit tranctons , 1-> non legit transactions
# Out:
# Class
# 0.0    187398
# 1.0       368
# Name: count, dtype: int64

# %%
legit_trans=credit_card_data[credit_card_data.Class==0]
non_legit_trans=credit_card_data[credit_card_data.Class==1]

# %%
print(legit_trans.shape)
print(non_legit_trans.shape)
# Out:
# (187398, 31)
# (368, 31)

# %% [markdown]
# # Under Sampling
# Building an sample dataset containing similar distribution of legit and non legit (fraudlent)transactions

# %%
# takig approx mix points in the legitsample
legit_sample=legit_trans.sample(n=368)

# %%
legit_sample.shape
# Out:
# (368, 31)

# %% [markdown]
# concatenate the two dataframes

# %%
new_dataset=pd.concat([legit_sample,non_legit_trans],axis=0)

# %%
new_dataset.head()
# Out:
#            Time        V1        V2        V3        V4        V5        V6  \
# 62362   50240.0 -0.934154  0.705075  1.991370 -0.360965  0.970368  0.176795
# 39238   39756.0  1.414655 -1.235626  0.463856 -1.413847 -1.640605 -0.407983
# 72869   54891.0  1.295257  0.400235 -1.832616  0.133846  2.551452  3.060135
# 116184  74174.0  1.238251 -0.287397  0.052777  0.198944 -0.173361  0.302150
# 88817   62308.0 -2.209816 -0.555353 -0.469295  0.957498  2.286729  0.046087
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 62362   1.253626 -0.270610 -0.473439  ...  0.080142  0.449368 -0.513561
# 39238  -1.263916  0.172810 -1.722932  ... -0.151309 -0.176694  0.107904
# 72869  -0.285335  0.756222 -0.209661  ... -0.105513 -0.385454 -0.154808
# 116184 -0.319236  0.152271  0.675870  ... -0.120459 -0.219052 -0.243750
# 88817   2.906240 -1.302464 -1.015695  ... -0.178397  1.351291 -0.089121
#
#              V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 178208  123525.0 -5.904921  4.439911 -8.631802  7.788684 -4.989580 -1.200144
# 181966  125200.0 -0.769172  1.342212 -2.171454 -0.151513 -0.648374 -0.973504
# 182992  125612.0  1.889618  1.073099 -1.678018  4.173268  1.015516 -0.009389
# 183106  125658.0  0.224414  2.994499 -3.432458  3.986519  3.760233  0.165640
# 184379  126219.0 -1.141559  1.927650 -3.905356 -0.073943 -0.044858 -1.756999
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 178208 -7.674060  4.125761 -5.315778  ...  1.775030  1.266441 -0.199410
# 181966 -1.706658  0.313745 -1.982302  ... -0.036122 -0.753591 -0.047113
# 182992 -0.079706  0.064071 -0.714517  ...  0.203728  0.733796 -0.036560
# 183106  1.099378 -0.654557 -2.435416  ...  0.491337 -0.984223 -0.421979
# 184379 -1.217416  0.364563 -2.770148  ...  0.102081 -0.531496 -0.328741
#
# ...

# %%
new_dataset.shape
# Out:
# (736, 31)
